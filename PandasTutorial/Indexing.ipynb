# %%
import pandas as pd

# %%
smartWatches=pd.read_csv('C:/Users/HP/.cache/kagglehub/datasets/rkiattisak/smart-watch-prices/versions/1/smart watch prices.csv',
            index_col=0)  # Setting the first column as index
pd.set_option('display.max_rows',4)  # Display maximum 4 rows of a dataframe
smartWatches
# Out:
#                    Model Operating System                Connectivity  \
# Brand
# Apple     Watch Series 7          watchOS  Bluetooth, Wi-Fi, Cellular
# Samsung   Galaxy Watch 4          Wear OS  Bluetooth, Wi-Fi, Cellular
# ...                  ...              ...                         ...
# Oppo          Watch Free          ColorOS            Bluetooth, Wi-Fi
# TicWatch           Pro 3          Wear OS  Bluetooth, Wi-Fi, Cellular
#
#          Display Type  Display Size (inches) Resolution  \
# Brand
# Apple          Retina                   1.90  396 x 484
# Samsung        AMOLED                   1.40  450 x 450
# ...               ...                    ...        ...
# Oppo           AMOLED                   1.64  326 x 326
# TicWatch       AMOLED                   1.40  454 x 454
#
#          Water Resistance (meters) Battery Life (days) Heart Rate Monitor  \
# Brand
# Apple                           50                  18                Yes
# ...

# %%
smartWatches.iloc[0]  # Accessing the first row using iloc
# Out:
# Model               Watch Series 7
# Operating System           watchOS
#                          ...
# NFC                            Yes
# Price (USD)                  $399
# Name: Apple, Length: 12, dtype: object

# %%
smartWatches.iloc[:,0]
# Out:
# Brand
# Apple       Watch Series 7
# Samsung     Galaxy Watch 4
#                  ...
# Oppo            Watch Free
# TicWatch             Pro 3
# Name: Model, Length: 379, dtype: object

# %%
smartWatches.iloc[:3,0]
# Out:
# Brand
# Apple      Watch Series 7
# Samsung    Galaxy Watch 4
# Garmin             Venu 2
# Name: Model, dtype: object

# %%
smartWatches.iloc[1:3,0]
# Out:
# Brand
# Samsung    Galaxy Watch 4
# Garmin             Venu 2
# Name: Model, dtype: object

# %% [markdown]
# Assigning Data

# %%
# Assigning data into the DataFrame column
smartWatches['Connectivity'] = 'Yes'
smartWatches
# Out:
#                    Model Operating System Connectivity Display Type  \
# Brand
# Apple     Watch Series 7          watchOS          Yes       Retina
# Samsung   Galaxy Watch 4          Wear OS          Yes       AMOLED
# ...                  ...              ...          ...          ...
# Oppo          Watch Free          ColorOS          Yes       AMOLED
# TicWatch           Pro 3          Wear OS          Yes       AMOLED
#
#           Display Size (inches) Resolution Water Resistance (meters)  \
# Brand
# Apple                      1.90  396 x 484                        50
# Samsung                    1.40  450 x 450                        50
# ...                         ...        ...                       ...
# Oppo                       1.64  326 x 326                        50
# TicWatch                   1.40  454 x 454                        50
#
#          Battery Life (days) Heart Rate Monitor  GPS  NFC Price (USD)
# Brand
# ...

# %%
# Assigning data into the DataFrame column
smartWatches['Used'] = 'No'
smartWatches
# Out:
#                    Model Operating System Connectivity Display Type  \
# Brand
# Apple     Watch Series 7          watchOS          Yes       Retina
# Samsung   Galaxy Watch 4          Wear OS          Yes       AMOLED
# ...                  ...              ...          ...          ...
# Oppo          Watch Free          ColorOS          Yes       AMOLED
# TicWatch           Pro 3          Wear OS          Yes       AMOLED
#
#           Display Size (inches) Resolution Water Resistance (meters)  \
# Brand
# Apple                      1.90  396 x 484                        50
# Samsung                    1.40  450 x 450                        50
# ...                         ...        ...                       ...
# Oppo                       1.64  326 x 326                        50
# TicWatch                   1.40  454 x 454                        50
#
#          Battery Life (days) Heart Rate Monitor  GPS  NFC Price (USD) Used
# Brand
# ...
