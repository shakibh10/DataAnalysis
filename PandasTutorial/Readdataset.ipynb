# %%
import pandas as pd

# %%
smart_watches =  pd.read_csv('C:/Users/HP/.cache/kagglehub/datasets/rkiattisak/smart-watch-prices/versions/1/smart watch prices.csv')

# %%
smart_watches.shape
# Out:
# (379, 13)

# %%
smart_watches.head()
# Out:
#      Brand           Model Operating System                Connectivity  \
# 0    Apple  Watch Series 7          watchOS  Bluetooth, Wi-Fi, Cellular
# 1  Samsung  Galaxy Watch 4          Wear OS  Bluetooth, Wi-Fi, Cellular
# 2   Garmin          Venu 2        Garmin OS            Bluetooth, Wi-Fi
# 3   Fitbit         Versa 3        Fitbit OS            Bluetooth, Wi-Fi
# 4   Fossil           Gen 6          Wear OS            Bluetooth, Wi-Fi
#
#   Display Type  Display Size (inches) Resolution Water Resistance (meters)  \
# 0       Retina                   1.90  396 x 484                        50
# 1       AMOLED                   1.40  450 x 450                        50
# 2       AMOLED                   1.30  416 x 416                        50
# 3       AMOLED                   1.58  336 x 336                        50
# 4       AMOLED                   1.28  416 x 416                        30
#
#   Battery Life (days) Heart Rate Monitor  GPS  NFC Price (USD)
# 0                  18                Yes  Yes  Yes       $399
# 1                  40                Yes  Yes  Yes       $249
# 2                  11                Yes  Yes   No       $399
# 3                   6                Yes  Yes  Yes       $229
# 4                  24                Yes  Yes  Yes       $299

# %%
smart_watches =  pd.read_csv('C:/Users/HP/.cache/kagglehub/datasets/rkiattisak/smart-watch-prices/versions/1/smart watch prices.csv',
                             index_col=0)
smart_watches.head()
# Out:
#                   Model Operating System                Connectivity  \
# Brand
# Apple    Watch Series 7          watchOS  Bluetooth, Wi-Fi, Cellular
# Samsung  Galaxy Watch 4          Wear OS  Bluetooth, Wi-Fi, Cellular
# Garmin           Venu 2        Garmin OS            Bluetooth, Wi-Fi
# Fitbit          Versa 3        Fitbit OS            Bluetooth, Wi-Fi
# Fossil            Gen 6          Wear OS            Bluetooth, Wi-Fi
#
#         Display Type  Display Size (inches) Resolution  \
# Brand
# Apple         Retina                   1.90  396 x 484
# Samsung       AMOLED                   1.40  450 x 450
# Garmin        AMOLED                   1.30  416 x 416
# Fitbit        AMOLED                   1.58  336 x 336
# Fossil        AMOLED                   1.28  416 x 416
#
#         Water Resistance (meters) Battery Life (days) Heart Rate Monitor  GPS  \
# Brand
# Apple                          50                  18                Yes  Yes
# Samsung                        50                  40                Yes  Yes
# Garmin                         50                  11                Yes  Yes
# Fitbit                         50                   6                Yes  Yes
# Fossil                         30                  24                Yes  Yes
#
#          NFC Price (USD)
# Brand
# Apple    Yes       $399
# Samsung  Yes       $249
# Garmin    No       $399
# Fitbit   Yes       $229
# Fossil   Yes       $299
